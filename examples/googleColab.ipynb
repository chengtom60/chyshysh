# %% [markdown]
# # Installing the OpenBB Platform in Google Colab
#
# This notebook will install the OpenBB Platform, fetch some data and prepare it for display as a bar chart.
#
# Sign up for a free account here: https://my.openbb.co

# %%
# Install the OpenBB Platform with all available extensions.
# Messages indicating package version conflicts at the end of installation can be safely ignored.

# !pip install openbb[all]

# There is also a nightly distribution available, openbb-nightly
# Out:
# Collecting openbb[all]
#   Downloading openbb-4.4.5-py3-none-any.whl.metadata (12 kB)
# Collecting openbb-alpha-vantage<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_alpha_vantage-1.4.2-py3-none-any.whl.metadata (910 bytes)
# Collecting openbb-benzinga<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_benzinga-1.4.2-py3-none-any.whl.metadata (882 bytes)
# Collecting openbb-biztoc<2.0.0,>=1.4.3 (from openbb[all])
#   Downloading openbb_biztoc-1.4.3-py3-none-any.whl.metadata (893 bytes)
# Collecting openbb-bls<2.0.0,>=1.1.3 (from openbb[all])
#   Downloading openbb_bls-1.1.3-py3-none-any.whl.metadata (1.2 kB)
# Collecting openbb-cboe<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_cboe-1.4.2-py3-none-any.whl.metadata (957 bytes)
# Collecting openbb-cftc<2.0.0,>=1.1.2 (from openbb[all])
#   Downloading openbb_cftc-1.1.2-py3-none-any.whl.metadata (1.4 kB)
# Collecting openbb-charting<3.0.0,>=2.3.5 (from openbb[all])
#   Downloading openbb_charting-2.3.5-py3-none-any.whl.metadata (6.6 kB)
# Collecting openbb-commodity<2.0.0,>=1.3.2 (from openbb[all])
#   Downloading openbb_commodity-1.3.2-py3-none-any.whl.metadata (904 bytes)
# Collecting openbb-core<2.0.0,>=1.4.8 (from openbb[all])
#   Downloading openbb_core-1.4.8-py3-none-any.whl.metadata (3.4 kB)
# Collecting openbb-crypto<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_crypto-1.4.2-py3-none-any.whl.metadata (896 bytes)
# Collecting openbb-currency<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_currency-1.4.2-py3-none-any.whl.metadata (897 bytes)
# Collecting openbb-deribit<2.0.0,>=1.0.2 (from openbb[all])
#   Downloading openbb_deribit-1.0.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting openbb-derivatives<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_derivatives-1.4.2-py3-none-any.whl.metadata (861 bytes)
# Collecting openbb-ecb<2.0.0,>=1.4.3 (from openbb[all])
#   Downloading openbb_ecb-1.4.3-py3-none-any.whl.metadata (903 bytes)
# Collecting openbb-econdb<2.0.0,>=1.3.2 (from openbb[all])
#   Downloading openbb_econdb-1.3.2-py3-none-any.whl.metadata (965 bytes)
# Collecting openbb-econometrics<2.0.0,>=1.5.4 (from openbb[all])
#   Downloading openbb_econometrics-1.5.4-py3-none-any.whl.metadata (1.0 kB)
# Collecting openbb-economy<2.0.0,>=1.4.3 (from openbb[all])
#   Downloading openbb_economy-1.4.3-py3-none-any.whl.metadata (902 bytes)
# Collecting openbb-equity<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_equity-1.4.2-py3-none-any.whl.metadata (1.4 kB)
# Collecting openbb-etf<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_etf-1.4.2-py3-none-any.whl.metadata (781 bytes)
# Collecting openbb-famafrench<2.0.0,>=1.0.0 (from openbb[all])
#   Downloading openbb_famafrench-1.0.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting openbb-federal-reserve<2.0.0,>=1.4.4 (from openbb[all])
#   Downloading openbb_federal_reserve-1.4.4-py3-none-any.whl.metadata (982 bytes)
# Collecting openbb-finra<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_finra-1.4.2-py3-none-any.whl.metadata (860 bytes)
# Collecting openbb-finviz<2.0.0,>=1.3.2 (from openbb[all])
#   Downloading openbb_finviz-1.3.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting openbb-fixedincome<2.0.0,>=1.4.4 (from openbb[all])
#   Downloading openbb_fixedincome-1.4.4-py3-none-any.whl.metadata (1.0 kB)
# Collecting openbb-fmp<2.0.0,>=1.4.3 (from openbb[all])
#   Downloading openbb_fmp-1.4.3-py3-none-any.whl.metadata (911 bytes)
# Collecting openbb-fred<2.0.0,>=1.4.5 (from openbb[all])
#   Downloading openbb_fred-1.4.5-py3-none-any.whl.metadata (879 bytes)
# Collecting openbb-government-us<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_government_us-1.4.2-py3-none-any.whl.metadata (948 bytes)
# Collecting openbb-imf<2.0.0,>=1.1.2 (from openbb[all])
#   Downloading openbb_imf-1.1.2-py3-none-any.whl.metadata (1.9 kB)
# Collecting openbb-index<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_index-1.4.2-py3-none-any.whl.metadata (897 bytes)
# Collecting openbb-intrinio<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_intrinio-1.4.2-py3-none-any.whl.metadata (925 bytes)
# Collecting openbb-mcp-server<2.0.0,>=1.0.0 (from openbb[all])
#   Downloading openbb_mcp_server-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting openbb-multpl<2.0.0,>=1.1.2 (from openbb[all])
#   Downloading openbb_multpl-1.1.2-py3-none-any.whl.metadata (694 bytes)
# Collecting openbb-nasdaq<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_nasdaq-1.4.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting openbb-news<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_news-1.4.2-py3-none-any.whl.metadata (855 bytes)
# Collecting openbb-oecd<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_oecd-1.4.2-py3-none-any.whl.metadata (939 bytes)
# Collecting openbb-platform-api<2.0.0,>=1.1.11 (from openbb[all])
#   Downloading openbb_platform_api-1.1.13-py3-none-any.whl.metadata (24 kB)
# Collecting openbb-polygon<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_polygon-1.4.2-py3-none-any.whl.metadata (871 bytes)
# Collecting openbb-quantitative<2.0.0,>=1.4.4 (from openbb[all])
#   Downloading openbb_quantitative-1.4.4-py3-none-any.whl.metadata (1.1 kB)
# Collecting openbb-regulators<2.0.0,>=1.4.3 (from openbb[all])
#   Downloading openbb_regulators-1.4.3-py3-none-any.whl.metadata (936 bytes)
# Collecting openbb-sec<2.0.0,>=1.4.4 (from openbb[all])
#   Downloading openbb_sec-1.4.5-py3-none-any.whl.metadata (1.2 kB)
# Collecting openbb-seeking-alpha<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_seeking_alpha-1.4.2-py3-none-any.whl.metadata (906 bytes)
# Collecting openbb-stockgrid<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_stockgrid-1.4.2-py3-none-any.whl.metadata (932 bytes)
# Collecting openbb-technical<2.0.0,>=1.4.4 (from openbb[all])
#   Downloading openbb_technical-1.4.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting openbb-tiingo<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_tiingo-1.4.2-py3-none-any.whl.metadata (870 bytes)
# Collecting openbb-tmx<2.0.0,>=1.3.3 (from openbb[all])
#   Downloading openbb_tmx-1.3.3-py3-none-any.whl.metadata (3.5 kB)
# Collecting openbb-tradier<2.0.0,>=1.3.2 (from openbb[all])
#   Downloading openbb_tradier-1.3.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting openbb-tradingeconomics<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_tradingeconomics-1.4.2-py3-none-any.whl.metadata (929 bytes)
# Collecting openbb-us-eia<2.0.0,>=1.1.2 (from openbb[all])
#   Downloading openbb_us_eia-1.1.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting openbb-wsj<2.0.0,>=1.4.2 (from openbb[all])
#   Downloading openbb_wsj-1.4.2-py3-none-any.whl.metadata (860 bytes)
# Collecting openbb-yfinance<2.0.0,>=1.4.7 (from openbb[all])
#   Downloading openbb_yfinance-1.4.7-py3-none-any.whl.metadata (966 bytes)
# Collecting aiohttp-client-cache<0.12.0,>=0.11.0 (from openbb-cboe<2.0.0,>=1.4.2->openbb[all])
#   Downloading aiohttp_client_cache-0.11.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting aiosqlite<0.21.0,>=0.20.0 (from openbb-cboe<2.0.0,>=1.4.2->openbb[all])
#   Downloading aiosqlite-0.20.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: nbformat<6.0.0,>=5.10.0 in /usr/local/lib/python3.11/dist-packages (from openbb-charting<3.0.0,>=2.3.5->openbb[all]) (5.10.4)
# Collecting pandas-ta-openbb<0.5.0,>=0.4.20 (from openbb-charting<3.0.0,>=2.3.5->openbb[all])
#   Downloading pandas_ta_openbb-0.4.22-py3-none-any.whl.metadata (9.0 kB)
# Collecting plotly<7.0.0,>=6.2.0 (from openbb-charting<3.0.0,>=2.3.5->openbb[all])
#   Downloading plotly-6.2.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.12.12 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.8->openbb[all]) (3.12.14)
# Collecting fastapi<0.116,>=0.115 (from openbb-core<2.0.0,>=1.4.8->openbb[all])
#   Downloading fastapi-0.115.14-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: html5lib<2.0,>=1.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.8->openbb[all]) (1.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.8->openbb[all]) (8.7.0)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.8->openbb[all]) (2.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.8->openbb[all]) (2.11.7)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.8->openbb[all]) (2.10.1)
# Collecting python-dotenv<2.0.0,>=1.0.0 (from openbb-core<2.0.0,>=1.4.8->openbb[all])
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: python-multipart<0.0.21,>=0.0.20 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.8->openbb[all]) (0.0.20)
# Collecting requests<3.0.0,>=2.32.4 (from openbb-core<2.0.0,>=1.4.8->openbb[all])
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: ruff<0.13,>=0.12 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.8->openbb[all]) (0.12.4)
# Collecting uuid7<0.2.0,>=0.1.0 (from openbb-core<2.0.0,>=1.4.8->openbb[all])
#   Downloading uuid7-0.1.0-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting uvicorn<0.35.0,>=0.34.2 (from openbb-core<2.0.0,>=1.4.8->openbb[all])
#   Downloading uvicorn-0.34.3-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: websockets<16.0,>=15.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.8->openbb[all]) (15.0.1)
# Collecting async-lru<3.0.0,>=2.0.4 (from openbb-deribit<2.0.0,>=1.0.2->openbb[all])
#   Downloading async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Collecting xmltodict<0.14.0,>=0.13.0 (from openbb-ecb<2.0.0,>=1.4.3->openbb[all])
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting arch<8.0,>=7.2 (from openbb-econometrics<2.0.0,>=1.5.4->openbb[all])
#   Downloading arch-7.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting linearmodels<7,>=6 (from openbb-econometrics<2.0.0,>=1.5.4->openbb[all])
#   Downloading linearmodels-6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.13.4 in /usr/local/lib/python3.11/dist-packages (from openbb-federal-reserve<2.0.0,>=1.4.4->openbb[all]) (4.13.4)
# Collecting finvizfinance<2.0.0,>=1.1.0 (from openbb-finviz<2.0.0,>=1.3.2->openbb[all])
#   Downloading finvizfinance-1.1.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting random-user-agent<2.0.0,>=1.0.1 (from openbb-government-us<2.0.0,>=1.4.2->openbb[all])
#   Downloading random_user_agent-1.0.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting requests-cache<2.0.0,>=1.1.0 (from openbb-intrinio<2.0.0,>=1.4.2->openbb[all])
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting fastmcp<3.0.0,>=2.10.5 (from openbb-mcp-server<2.0.0,>=1.0.0->openbb[all])
#   Downloading fastmcp-2.10.6-py3-none-any.whl.metadata (17 kB)
# Collecting nasdaq-data-link<2.0.0,>=1.0.4 (from openbb-nasdaq<2.0.0,>=1.4.2->openbb[all])
#   Downloading Nasdaq_Data_Link-1.0.4-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting defusedxml<0.9.0,>=0.8.0rc2 (from openbb-oecd<2.0.0,>=1.4.2->openbb[all])
#   Downloading defusedxml-0.8.0rc2-py2.py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: urllib3>1.26.16 in /usr/local/lib/python3.11/dist-packages (from openbb-oecd<2.0.0,>=1.4.2->openbb[all]) (2.5.0)
# Collecting deepdiff (from openbb-platform-api<2.0.0,>=1.1.11->openbb[all])
#   Downloading deepdiff-8.5.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting inscriptis<3.0.0,>=2.5.3 (from openbb-sec<2.0.0,>=1.4.4->openbb[all])
#   Downloading inscriptis-2.6.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: lxml<6.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from openbb-sec<2.0.0,>=1.4.4->openbb[all]) (5.4.0)
# Collecting trafilatura<3.0,>=2.0 (from openbb-sec<2.0.0,>=1.4.4->openbb[all])
#   Downloading trafilatura-2.0.0-py3-none-any.whl.metadata (12 kB)
# Collecting pytest-freezegun<0.5.0,>=0.4.2 (from openbb-stockgrid<2.0.0,>=1.4.2->openbb[all])
#   Downloading pytest_freezegun-0.4.2-py2.py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from openbb-technical<2.0.0,>=1.4.4->openbb[all]) (1.6.1)
# Collecting exchange-calendars<5.0.0,>=4.5.4 (from openbb-tmx<2.0.0,>=1.3.3->openbb[all])
#   Downloading exchange_calendars-4.11-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /usr/local/lib/python3.11/dist-packages (from openbb-us-eia<2.0.0,>=1.1.2->openbb[all]) (3.1.5)
# Requirement already satisfied: xlrd<3.0.0,>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from openbb-us-eia<2.0.0,>=1.1.2->openbb[all]) (2.0.2)
# Collecting curl-adapter>=1.1.0 (from openbb-yfinance<2.0.0,>=1.4.7->openbb[all])
#   Downloading curl_adapter-1.1.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting yfinance==0.2.58 (from openbb-yfinance<2.0.0,>=1.4.7->openbb[all])
#   Downloading yfinance-0.2.58-py2.py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.7->openbb[all]) (2.0.2)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.7->openbb[all]) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.7->openbb[all]) (4.3.8)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.7->openbb[all]) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.7->openbb[all]) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.7->openbb[all]) (3.18.2)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.7->openbb[all]) (0.12.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.12.12->openbb-core<2.0.0,>=1.4.8->openbb[all]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.12.12->openbb-core<2.0.0,>=1.4.8->openbb[all]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.12.12->openbb-core<2.0.0,>=1.4.8->openbb[all]) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.12.12->openbb-core<2.0.0,>=1.4.8->openbb[all]) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.12.12->openbb-core<2.0.0,>=1.4.8->openbb[all]) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.12.12->openbb-core<2.0.0,>=1.4.8->openbb[all]) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.12.12->openbb-core<2.0.0,>=1.4.8->openbb[all]) (1.20.1)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp-client-cache<0.12.0,>=0.11.0->openbb-cboe<2.0.0,>=1.4.2->openbb[all]) (2.2.0)
# Collecting url-normalize<2.0,>=1.4 (from aiohttp-client-cache<0.12.0,>=0.11.0->openbb-cboe<2.0.0,>=1.4.2->openbb[all])
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.11/dist-packages (from aiosqlite<0.21.0,>=0.20.0->openbb-cboe<2.0.0,>=1.4.2->openbb[all]) (4.14.1)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.11/dist-packages (from arch<8.0,>=7.2->openbb-econometrics<2.0.0,>=1.5.4->openbb[all]) (1.16.0)
# Requirement already satisfied: statsmodels>=0.12 in /usr/local/lib/python3.11/dist-packages (from arch<8.0,>=7.2->openbb-econometrics<2.0.0,>=1.5.4->openbb[all]) (0.14.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5.0.0,>=4.13.4->openbb-federal-reserve<2.0.0,>=1.4.4->openbb[all]) (2.7)
# Collecting pycurl>=7.45.5 (from curl-adapter>=1.1.0->openbb-yfinance<2.0.0,>=1.4.7->openbb[all])
#   Downloading pycurl-7.45.6-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: brotli in /usr/local/lib/python3.11/dist-packages (from curl-adapter>=1.1.0->openbb-yfinance<2.0.0,>=1.4.7->openbb[all]) (1.1.0)
# Collecting pyluach (from exchange-calendars<5.0.0,>=4.5.4->openbb-tmx<2.0.0,>=1.3.3->openbb[all])
#   Downloading pyluach-2.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/dist-packages (from exchange-calendars<5.0.0,>=4.5.4->openbb-tmx<2.0.0,>=1.3.3->openbb[all]) (0.12.1)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from exchange-calendars<5.0.0,>=4.5.4->openbb-tmx<2.0.0,>=1.3.3->openbb[all]) (2025.2)
# Collecting korean_lunar_calendar (from exchange-calendars<5.0.0,>=4.5.4->openbb-tmx<2.0.0,>=1.3.3->openbb[all])
#   Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.8->openbb[all])
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting authlib>=1.5.2 (from fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all])
#   Downloading authlib-1.6.1-py2.py3-none-any.whl.metadata (1.6 kB)
# Collecting cyclopts>=3.0.0 (from fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all])
#   Downloading cyclopts-3.22.3-py3-none-any.whl.metadata (11 kB)
# Collecting exceptiongroup>=1.2.2 (from fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all])
#   Downloading exceptiongroup-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all]) (0.28.1)
# Collecting mcp>=1.10.0 (from fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all])
#   Downloading mcp-1.12.2-py3-none-any.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.6 MB/s eta 0:00:00
# Collecting openapi-pydantic>=0.5.1 (from fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all])
#   Downloading openapi_pydantic-0.5.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pyperclip>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all]) (1.9.0)
# Requirement already satisfied: rich>=13.9.4 in /usr/local/lib/python3.11/dist-packages (from fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all]) (13.9.4)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.11/dist-packages (from html5lib<2.0,>=1.1->openbb-core<2.0.0,>=1.4.8->openbb[all]) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from html5lib<2.0,>=1.1->openbb-core<2.0.0,>=1.4.8->openbb[all]) (0.5.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.8.0->openbb-core<2.0.0,>=1.4.8->openbb[all]) (3.23.0)
# Collecting mypy-extensions>=0.4 (from linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.5.4->openbb[all])
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: Cython>=3.0.10 in /usr/local/lib/python3.11/dist-packages (from linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.5.4->openbb[all]) (3.0.12)
# Collecting pyhdfe>=0.1 (from linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.5.4->openbb[all])
#   Downloading pyhdfe-0.2.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting formulaic>=1.0.0 (from linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.5.4->openbb[all])
#   Downloading formulaic-1.2.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting setuptools-scm<9.0.0,>=8.0.0 (from setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.5.4->openbb[all])
#   Downloading setuptools_scm-8.3.1-py3-none-any.whl.metadata (7.0 kB)
# Collecting inflection>=0.3.1 (from nasdaq-data-link<2.0.0,>=1.0.4->openbb-nasdaq<2.0.0,>=1.4.2->openbb[all])
#   Downloading inflection-0.5.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from nasdaq-data-link<2.0.0,>=1.0.4->openbb-nasdaq<2.0.0,>=1.4.2->openbb[all]) (2.9.0.post0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from nasdaq-data-link<2.0.0,>=1.0.4->openbb-nasdaq<2.0.0,>=1.4.2->openbb[all]) (10.7.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.3.5->openbb[all]) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.3.5->openbb[all]) (4.25.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.3.5->openbb[all]) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.11/dist-packages (from nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.3.5->openbb[all]) (5.7.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl<4.0.0,>=3.1.5->openbb-us-eia<2.0.0,>=1.1.2->openbb[all]) (2.0.0)
# Collecting numba>=0.61.0 (from pandas-ta-openbb<0.5.0,>=0.4.20->openbb-charting<3.0.0,>=2.3.5->openbb[all])
#   Downloading numba-0.61.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting scipy>=1.8 (from arch<8.0,>=7.2->openbb-econometrics<2.0.0,>=1.5.4->openbb[all])
#   Downloading scipy-1.15.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from plotly<7.0.0,>=6.2.0->openbb-charting<3.0.0,>=2.3.5->openbb[all]) (1.48.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly<7.0.0,>=6.2.0->openbb-charting<3.0.0,>=2.3.5->openbb[all]) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.4.8->openbb[all]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.4.8->openbb[all]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.4.8->openbb[all]) (0.4.1)
# Collecting freezegun>0.3 (from pytest-freezegun<0.5.0,>=0.4.2->openbb-stockgrid<2.0.0,>=1.4.2->openbb[all])
#   Downloading freezegun-1.5.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pytest>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from pytest-freezegun<0.5.0,>=0.4.2->openbb-stockgrid<2.0.0,>=1.4.2->openbb[all]) (8.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.4->openbb-core<2.0.0,>=1.4.8->openbb[all]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.4->openbb-core<2.0.0,>=1.4.8->openbb[all]) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.4->openbb-core<2.0.0,>=1.4.8->openbb[all]) (2025.7.14)
# Collecting cattrs>=22.2 (from requests-cache<2.0.0,>=1.1.0->openbb-intrinio<2.0.0,>=1.4.2->openbb[all])
#   Downloading cattrs-25.1.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.6.0->openbb-technical<2.0.0,>=1.4.4->openbb[all]) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.6.0->openbb-technical<2.0.0,>=1.4.4->openbb[all]) (3.6.0)
# Collecting courlan>=1.3.2 (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.4->openbb[all])
#   Downloading courlan-1.3.2-py3-none-any.whl.metadata (17 kB)
# Collecting htmldate>=1.9.2 (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.4->openbb[all])
#   Downloading htmldate-1.9.3-py3-none-any.whl.metadata (10 kB)
# Collecting justext>=3.0.1 (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.4->openbb[all])
#   Downloading justext-3.0.2-py2.py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn<0.35.0,>=0.34.2->openbb-core<2.0.0,>=1.4.8->openbb[all]) (8.2.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn<0.35.0,>=0.34.2->openbb-core<2.0.0,>=1.4.8->openbb[all]) (0.16.0)
# Collecting orderly-set<6,>=5.4.1 (from deepdiff->openbb-platform-api<2.0.0,>=1.1.11->openbb[all])
#   Downloading orderly_set-5.5.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.11/dist-packages (from authlib>=1.5.2->fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all]) (43.0.3)
# Requirement already satisfied: babel>=2.16.0 in /usr/local/lib/python3.11/dist-packages (from courlan>=1.3.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.4->openbb[all]) (2.17.0)
# Collecting tld>=0.13 (from courlan>=1.3.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.4->openbb[all])
#   Downloading tld-0.13.1-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from curl_cffi>=0.7->yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.7->openbb[all]) (1.17.1)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.11/dist-packages (from cyclopts>=3.0.0->fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all]) (0.17.0)
# Collecting rich-rst<2.0.0,>=1.3.1 (from cyclopts>=3.0.0->fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all])
#   Downloading rich_rst-1.3.1-py3-none-any.whl.metadata (6.0 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=1.0.0->linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.5.4->openbb[all])
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=1.0.0->linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.5.4->openbb[all]) (1.17.2)
# Collecting dateparser>=1.1.2 (from htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.4->openbb[all])
#   Downloading dateparser-1.2.2-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.28.1->fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all]) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.28.1->fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all]) (1.0.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.3.5->openbb[all]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.3.5->openbb[all]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.3.5->openbb[all]) (0.26.0)
# Collecting httpx-sse>=0.4 (from mcp>=1.10.0->fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all])
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting pydantic-settings>=2.5.2 (from mcp>=1.10.0->fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all])
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting sse-starlette>=1.6.1 (from mcp>=1.10.0->fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all])
#   Downloading sse_starlette-3.0.2-py3-none-any.whl.metadata (11 kB)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba>=0.61.0->pandas-ta-openbb<0.5.0,>=0.4.20->openbb-charting<3.0.0,>=2.3.5->openbb[all])
#   Downloading llvmlite-0.44.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Collecting email-validator>=2.0.0 (from pydantic[email]>=2.11.7->fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all])
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.11/dist-packages (from pytest>=3.0.0->pytest-freezegun<0.5.0,>=0.4.2->openbb-stockgrid<2.0.0,>=1.4.2->openbb[all]) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest>=3.0.0->pytest-freezegun<0.5.0,>=0.4.2->openbb-stockgrid<2.0.0,>=1.4.2->openbb[all]) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from pytest>=3.0.0->pytest-freezegun<0.5.0,>=0.4.2->openbb-stockgrid<2.0.0,>=1.4.2->openbb[all]) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.9.4->fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all]) (3.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.5.4->openbb[all]) (75.2.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.12->arch<8.0,>=7.2->openbb-econometrics<2.0.0,>=1.5.4->openbb[all]) (1.0.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.28.1->fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all]) (1.3.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.7->openbb[all]) (2.22)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.11/dist-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.4->openbb[all]) (2024.11.6)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.11/dist-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.4->openbb[all]) (5.3.1)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all])
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting lxml_html_clean (from lxml[html_clean]>=4.4.2->justext>=3.0.1->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.4->openbb[all])
#   Downloading lxml_html_clean-0.4.2-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all]) (0.1.2)
# Requirement already satisfied: docutils in /usr/local/lib/python3.11/dist-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=3.0.0->fastmcp<3.0.0,>=2.10.5->openbb-mcp-server<2.0.0,>=1.0.0->openbb[all]) (0.21.2)
# Downloading openbb_alpha_vantage-1.4.2-py3-none-any.whl (9.9 kB)
# Downloading openbb_benzinga-1.4.2-py3-none-any.whl (14 kB)
# Downloading openbb_biztoc-1.4.3-py3-none-any.whl (4.8 kB)
# Downloading openbb_bls-1.1.3-py3-none-any.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 70.2 MB/s eta 0:00:00
# Downloading openbb_cboe-1.4.2-py3-none-any.whl (27 kB)
# Downloading openbb_cftc-1.1.2-py3-none-any.whl (12 kB)
# Downloading openbb_charting-2.3.5-py3-none-any.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 84.0 MB/s eta 0:00:00
# Downloading openbb_commodity-1.3.2-py3-none-any.whl (3.4 kB)
# Downloading openbb_core-1.4.8-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.2/294.2 kB 13.0 MB/s eta 0:00:00
# Downloading openbb_crypto-1.4.2-py3-none-any.whl (4.0 kB)
# Downloading openbb_currency-1.4.2-py3-none-any.whl (4.9 kB)
# Downloading openbb_deribit-1.0.2-py3-none-any.whl (17 kB)
# Downloading openbb_derivatives-1.4.2-py3-none-any.whl (10 kB)
# Downloading openbb_ecb-1.4.3-py3-none-any.whl (11 kB)
# Downloading openbb_econdb-1.3.2-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.0/97.0 kB 5.7 MB/s eta 0:00:00
# Downloading openbb_econometrics-1.5.4-py3-none-any.whl (11 kB)
# Downloading openbb_economy-1.4.3-py3-none-any.whl (17 kB)
# Downloading openbb_equity-1.4.2-py3-none-any.whl (16 kB)
# Downloading openbb_etf-1.4.2-py3-none-any.whl (5.1 kB)
# Downloading openbb_famafrench-1.0.0-py3-none-any.whl (38 kB)
# Downloading openbb_federal_reserve-1.4.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 5.1 MB/s eta 0:00:00
# Downloading openbb_finra-1.4.2-py3-none-any.whl (7.5 kB)
# Downloading openbb_finviz-1.3.2-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 2.9 MB/s eta 0:00:00
# Downloading openbb_fixedincome-1.4.4-py3-none-any.whl (12 kB)
# Downloading openbb_fmp-1.4.3-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.9/111.9 kB 7.4 MB/s eta 0:00:00
# Downloading openbb_fred-1.4.5-py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.4/108.4 kB 8.4 MB/s eta 0:00:00
# Downloading openbb_government_us-1.4.2-py3-none-any.whl (7.7 kB)
# Downloading openbb_imf-1.1.2-py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.3/108.3 kB 6.5 MB/s eta 0:00:00
# Downloading openbb_index-1.4.2-py3-none-any.whl (4.2 kB)
# Downloading openbb_intrinio-1.4.2-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 6.5 MB/s eta 0:00:00
# Downloading openbb_mcp_server-1.0.0-py3-none-any.whl (13 kB)
# Downloading openbb_multpl-1.1.2-py3-none-any.whl (4.3 kB)
# Downloading openbb_nasdaq-1.4.2-py3-none-any.whl (29 kB)
# Downloading openbb_news-1.4.2-py3-none-any.whl (2.8 kB)
# Downloading openbb_oecd-1.4.2-py3-none-any.whl (36 kB)
# Downloading openbb_platform_api-1.1.13-py3-none-any.whl (38 kB)
# Downloading openbb_polygon-1.4.2-py3-none-any.whl (32 kB)
# Downloading openbb_quantitative-1.4.4-py3-none-any.whl (15 kB)
# Downloading openbb_regulators-1.4.3-py3-none-any.whl (5.3 kB)
# Downloading openbb_sec-1.4.5-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 kB 4.6 MB/s eta 0:00:00
# Downloading openbb_seeking_alpha-1.4.2-py3-none-any.whl (10 kB)
# Downloading openbb_stockgrid-1.4.2-py3-none-any.whl (3.1 kB)
# Downloading openbb_technical-1.4.4-py3-none-any.whl (26 kB)
# Downloading openbb_tiingo-1.4.2-py3-none-any.whl (13 kB)
# Downloading openbb_tmx-1.3.3-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.1 MB/s eta 0:00:00
# Downloading openbb_tradier-1.3.2-py3-none-any.whl (13 kB)
# Downloading openbb_tradingeconomics-1.4.2-py3-none-any.whl (8.3 kB)
# Downloading openbb_us_eia-1.1.2-py3-none-any.whl (28 kB)
# Downloading openbb_wsj-1.4.2-py3-none-any.whl (6.1 kB)
# Downloading openbb_yfinance-1.4.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.6/66.6 kB 4.5 MB/s eta 0:00:00
# Downloading yfinance-0.2.58-py2.py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.7/113.7 kB 8.2 MB/s eta 0:00:00
# Downloading openbb-4.4.5-py3-none-any.whl (368 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 368.3/368.3 kB 22.8 MB/s eta 0:00:00
# Downloading aiohttp_client_cache-0.11.1-py3-none-any.whl (32 kB)
# Downloading aiosqlite-0.20.0-py3-none-any.whl (15 kB)
# Downloading arch-7.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (985 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 985.3/985.3 kB 35.8 MB/s eta 0:00:00
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading curl_adapter-1.1.0-py3-none-any.whl (30 kB)
# Downloading defusedxml-0.8.0rc2-py2.py3-none-any.whl (25 kB)
# Downloading exchange_calendars-4.11-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.6/203.6 kB 12.2 MB/s eta 0:00:00
# Downloading fastapi-0.115.14-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.5/95.5 kB 6.9 MB/s eta 0:00:00
# Downloading fastmcp-2.10.6-py3-none-any.whl (202 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.6/202.6 kB 9.1 MB/s eta 0:00:00
# Downloading finvizfinance-1.1.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.1 MB/s eta 0:00:00
# Downloading inscriptis-2.6.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 3.1 MB/s eta 0:00:00
# Downloading linearmodels-6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 44.1 MB/s eta 0:00:00
# Downloading Nasdaq_Data_Link-1.0.4-py2.py3-none-any.whl (28 kB)
# Downloading pandas_ta_openbb-0.4.22-py3-none-any.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 17.4 MB/s eta 0:00:00
# Downloading plotly-6.2.0-py3-none-any.whl (9.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 73.8 MB/s eta 0:00:00
# Downloading pytest_freezegun-0.4.2-py2.py3-none-any.whl (4.6 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading random_user_agent-1.0.1-py3-none-any.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 61.5 MB/s eta 0:00:00
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 4.8 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.8 MB/s eta 0:00:00
# Downloading trafilatura-2.0.0-py3-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 9.0 MB/s eta 0:00:00
# Downloading uuid7-0.1.0-py2.py3-none-any.whl (7.5 kB)
# Downloading uvicorn-0.34.3-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 3.9 MB/s eta 0:00:00
# Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Downloading deepdiff-8.5.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.1/85.1 kB 3.3 MB/s eta 0:00:00
# Downloading authlib-1.6.1-py2.py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.3/239.3 kB 14.6 MB/s eta 0:00:00
# Downloading cattrs-25.1.1-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 4.2 MB/s eta 0:00:00
# Downloading courlan-1.3.2-py3-none-any.whl (33 kB)
# Downloading cyclopts-3.22.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 4.7 MB/s eta 0:00:00
# Downloading exceptiongroup-1.3.0-py3-none-any.whl (16 kB)
# Downloading formulaic-1.2.0-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 5.7 MB/s eta 0:00:00
# Downloading freezegun-1.5.3-py3-none-any.whl (19 kB)
# Downloading htmldate-1.9.3-py3-none-any.whl (31 kB)
# Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Downloading justext-3.0.2-py2.py3-none-any.whl (837 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 837.9/837.9 kB 16.0 MB/s eta 0:00:00
# Downloading mcp-1.12.2-py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.5/158.5 kB 2.2 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading numba-0.61.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 29.6 MB/s eta 0:00:00
# Downloading openapi_pydantic-0.5.1-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 6.0 MB/s eta 0:00:00
# Downloading orderly_set-5.5.0-py3-none-any.whl (13 kB)
# Downloading pycurl-7.45.6-cp311-cp311-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 19.3 MB/s eta 0:00:00
# Downloading pyhdfe-0.2.0-py3-none-any.whl (19 kB)
# Downloading scipy-1.15.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 19.3 MB/s eta 0:00:00
# Downloading setuptools_scm-8.3.1-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 2.8 MB/s eta 0:00:00
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.4 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Downloading pyluach-2.2.0-py3-none-any.whl (25 kB)
# Downloading dateparser-1.2.2-py3-none-any.whl (315 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.5/315.5 kB 24.0 MB/s eta 0:00:00
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Downloading llvmlite-0.44.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 15.9 MB/s eta 0:00:00
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 2.9 MB/s eta 0:00:00
# Downloading rich_rst-1.3.1-py3-none-any.whl (11 kB)
# Downloading sse_starlette-3.0.2-py3-none-any.whl (11 kB)
# Downloading tld-0.13.1-py2.py3-none-any.whl (274 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 20.7 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 24.4 MB/s eta 0:00:00
# Downloading lxml_html_clean-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: random-user-agent, korean_lunar_calendar, xmltodict, uvicorn, uuid7, url-normalize, tld, setuptools-scm, scipy, requests, python-dotenv, pyluach, pycurl, plotly, orderly-set, mypy-extensions, lxml_html_clean, llvmlite, interface-meta, inflection, httpx-sse, exceptiongroup, dnspython, defusedxml, cattrs, async-lru, aiosqlite, starlette, sse-starlette, requests-cache, pyhdfe, numba, inscriptis, freezegun, email-validator, deepdiff, dateparser, courlan, yfinance, rich-rst, pytest-freezegun, pydantic-settings, openapi-pydantic, nasdaq-data-link, justext, htmldate, formulaic, finvizfinance, fastapi, exchange-calendars, curl-adapter, authlib, aiohttp-client-cache, trafilatura, pandas-ta-openbb, openbb-core, mcp, linearmodels, cyclopts, arch, openbb-yfinance, openbb-wsj, openbb-us-eia, openbb-tradingeconomics, openbb-tradier, openbb-tmx, openbb-tiingo, openbb-technical, openbb-stockgrid, openbb-seeking-alpha, openbb-sec, openbb-regulators, openbb-quantitative, openbb-polygon, openbb-platform-api, openbb-oecd, openbb-news, openbb-multpl, openbb-intrinio, openbb-index, openbb-imf, openbb-government-us, openbb-fred, openbb-fmp, openbb-fixedincome, openbb-finviz, openbb-finra, openbb-federal-reserve, openbb-famafrench, openbb-etf, openbb-equity, openbb-economy, openbb-econometrics, openbb-econdb, openbb-ecb, openbb-derivatives, openbb-deribit, openbb-currency, openbb-crypto, openbb-commodity, openbb-charting, openbb-cftc, openbb-cboe, openbb-bls, openbb-biztoc, openbb-benzinga, openbb-alpha-vantage, fastmcp, openbb-nasdaq, openbb-mcp-server, openbb
#   Attempting uninstall: uvicorn
#     Found existing installation: uvicorn 0.35.0
#     Uninstalling uvicorn-0.35.0:
#       Successfully uninstalled uvicorn-0.35.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.0
#     Uninstalling scipy-1.16.0:
#       Successfully uninstalled scipy-1.16.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: defusedxml
#     Found existing installation: defusedxml 0.7.1
#     Uninstalling defusedxml-0.7.1:
#       Successfully uninstalled defusedxml-0.7.1
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.47.2
#     Uninstalling starlette-0.47.2:
#       Successfully uninstalled starlette-0.47.2
#   Attempting uninstall: numba
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.65
#     Uninstalling yfinance-0.2.65:
#       Successfully uninstalled yfinance-0.2.65
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.116.1
#     Uninstalling fastapi-0.116.1:
#       Successfully uninstalled fastapi-0.116.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.4 which is incompatible.
# Successfully installed aiohttp-client-cache-0.11.1 aiosqlite-0.20.0 arch-7.2.0 async-lru-2.0.5 authlib-1.6.1 cattrs-25.1.1 courlan-1.3.2 curl-adapter-1.1.0 cyclopts-3.22.3 dateparser-1.2.2 deepdiff-8.5.0 defusedxml-0.8.0rc2 dnspython-2.7.0 email-validator-2.2.0 exceptiongroup-1.3.0 exchange-calendars-4.11 fastapi-0.115.14 fastmcp-2.10.6 finvizfinance-1.1.1 formulaic-1.2.0 freezegun-1.5.3 htmldate-1.9.3 httpx-sse-0.4.1 inflection-0.5.1 inscriptis-2.6.0 interface-meta-1.3.0 justext-3.0.2 korean_lunar_calendar-0.3.1 linearmodels-6.1 llvmlite-0.44.0 lxml_html_clean-0.4.2 mcp-1.12.2 mypy-extensions-1.1.0 nasdaq-data-link-1.0.4 numba-0.61.2 openapi-pydantic-0.5.1 openbb-4.4.5 openbb-alpha-vantage-1.4.2 openbb-benzinga-1.4.2 openbb-biztoc-1.4.3 openbb-bls-1.1.3 openbb-cboe-1.4.2 openbb-cftc-1.1.2 openbb-charting-2.3.5 openbb-commodity-1.3.2 openbb-core-1.4.8 openbb-crypto-1.4.2 openbb-currency-1.4.2 openbb-deribit-1.0.2 openbb-derivatives-1.4.2 openbb-ecb-1.4.3 openbb-econdb-1.3.2 openbb-econometrics-1.5.4 openbb-economy-1.4.3 openbb-equity-1.4.2 openbb-etf-1.4.2 openbb-famafrench-1.0.0 openbb-federal-reserve-1.4.4 openbb-finra-1.4.2 openbb-finviz-1.3.2 openbb-fixedincome-1.4.4 openbb-fmp-1.4.3 openbb-fred-1.4.5 openbb-government-us-1.4.2 openbb-imf-1.1.2 openbb-index-1.4.2 openbb-intrinio-1.4.2 openbb-mcp-server-1.0.0 openbb-multpl-1.1.2 openbb-nasdaq-1.4.2 openbb-news-1.4.2 openbb-oecd-1.4.2 openbb-platform-api-1.1.13 openbb-polygon-1.4.2 openbb-quantitative-1.4.4 openbb-regulators-1.4.3 openbb-sec-1.4.5 openbb-seeking-alpha-1.4.2 openbb-stockgrid-1.4.2 openbb-technical-1.4.4 openbb-tiingo-1.4.2 openbb-tmx-1.3.3 openbb-tradier-1.3.2 openbb-tradingeconomics-1.4.2 openbb-us-eia-1.1.2 openbb-wsj-1.4.2 openbb-yfinance-1.4.7 orderly-set-5.5.0 pandas-ta-openbb-0.4.22 plotly-6.2.0 pycurl-7.45.6 pydantic-settings-2.10.1 pyhdfe-0.2.0 pyluach-2.2.0 pytest-freezegun-0.4.2 python-dotenv-1.1.1 random-user-agent-1.0.1 requests-2.32.4 requests-cache-1.2.1 rich-rst-1.3.1 scipy-1.15.3 setuptools-scm-8.3.1 sse-starlette-3.0.2 starlette-0.46.2 tld-0.13.1 trafilatura-2.0.0 url-normalize-1.4.3 uuid7-0.1.0 uvicorn-0.34.3 xmltodict-0.13.0 yfinance-0.2.58

# %%
# Before running this cell, restart the runtime by selecting, "Restart runtime", from the "Runtime" menu.

# Import statements - for many scenarios, the only import needed will be `from openbb import obb`
from typing import Literal
from IPython.display import display
from IPython.display import clear_output
import ipywidgets as widgets
import pandas as pd
import pandas_ta as ta
from datetime import datetime
from plotly import graph_objects as go

from openbb import obb

# %%
# Login to OpenBB Hub to retrieve stored API keys.
# https://my.openbb.co/app/platform/pat
# https://my.openbb.co/app/platform/api-keys

obb.account.login(pat="replace with your PAT")

# This is not required

# %%
# Verify that the credentials from Hub were loaded successfully.

obb.user.credentials
# Out:
# Credentials
#
# alpha_vantage_api_key: **********
# benzinga_api_key: None
# biztoc_api_key: None
# fmp_api_key: **********
# fred_api_key: **********
# intrinio_api_key: **********
# nasdaq_api_key: **********
# polygon_api_key: **********
# tiingo_token: None
# tradingeconomics_api_key: None

# %%
# Set the output preference, if desired. The examples below use Pandas DataFrames.

obb.user.preferences.output_type = "dataframe"

# %%
# Get Some Data
symbol = "SPY"

options = obb.derivatives.options.chains(symbol, provider="cboe")

options
# Out:
#          contract_symbol  expiration  strike option_type  volume   open  \
# 0     SPY231130C00387000  2023-11-30   387.0        call     7.0  67.60
# 1     SPY231130P00387000  2023-11-30   387.0         put     2.0   0.01
# 2     SPY231130C00388000  2023-11-30   388.0        call     1.0  66.47
# 3     SPY231130P00388000  2023-11-30   388.0         put     1.0   0.01
# 4     SPY231130C00389000  2023-11-30   389.0        call     0.0   0.00
# ...                  ...         ...     ...         ...     ...    ...
# 8215  SPY260116P00670000  2026-01-16   670.0         put     0.0   0.00
# 8216  SPY260116C00675000  2026-01-16   675.0        call     0.0   0.00
# 8217  SPY260116P00675000  2026-01-16   675.0         put     0.0   0.00
# 8218  SPY260116C00680000  2026-01-16   680.0        call     0.0   0.00
# 8219  SPY260116P00680000  2026-01-16   680.0         put     0.0   0.00
#
#       open_interest   high    low  implied_volatility  ...  last_trade_price  \
# 0               5.0  67.60  66.55              0.0000  ...             66.55
# 1             290.0   0.01   0.01              0.0000  ...              0.01
# 2               0.0  66.47  66.47              0.0000  ...             66.47
# 3               1.0   0.01   0.01              0.0000  ...              0.01
# 4               0.0   0.00   0.00              0.0000  ...              0.00
# ...             ...    ...    ...                 ...  ...               ...
# 8215            0.0   0.00   0.00              0.2367  ...            216.04
# 8216            0.0   0.00   0.00              0.1387  ...              0.00
# 8217            0.0   0.00   0.00              0.2385  ...              0.00
# 8218            0.0   0.00   0.00              0.1411  ...              0.00
# 8219            0.0   0.00   0.00              0.2432  ...            223.91
#
#            tick  prev_close  change  change_percent     rho  \
# 0          down       67.69  -1.135           -1.68  0.0003
# 1     no_change        0.00   0.005          100.00  0.0000
# 2          down       66.68  -0.210           -0.31  0.0003
# 3     no_change        0.00   0.005          100.00  0.0000
# 4     no_change       65.69   0.000            0.00  0.0003
# ...         ...         ...     ...             ...     ...
# 8215       down      215.44   0.000            0.00 -0.3427
# 8216  no_change        2.50   0.000            0.00  0.4385
# 8217  no_change      220.50   0.000            0.00 -0.3453
# 8218  no_change        2.50   0.000            0.00  0.4078
# 8219       down      225.50   0.000            0.00 -0.3478
#
#       last_trade_timestamp  dte     bid     ask
# 0      2023-11-30 12:27:59   -1   67.77   70.67
# 1      2023-11-30 09:30:12   -1    0.00    0.01
# 2      2023-11-30 09:42:00   -1   67.56   68.77
# 3      2023-11-30 10:16:04   -1    0.00    0.01
# 4                      NaT   -1   65.77   68.67
# ...                    ...  ...     ...     ...
# 8215   2023-11-20 12:31:47  777  211.56  216.50
# 8216                   NaT  777    0.00    5.00
# 8217                   NaT  777  216.50  221.50
# 8218                   NaT  777    0.00    5.00
# 8219   2023-11-27 14:07:53  777  221.50  226.50
#
# [8220 rows x 27 columns]

# %%
# Prepare A View - Volume and Open Interest by Expiration or Strike

def filter_options_data(options, by: Literal["expiration", "strike"] = "expiration"):
    data = pd.DataFrame()
    data["Total Open Interest"] = options.groupby(by)["open_interest"].sum()
    data["Call Open Interest"] = options[options["option_type"] == "call"].groupby(by)["open_interest"].sum()
    data["Put Open Interest"] = options[options["option_type"] == "put"].groupby(by)["open_interest"].sum()
    data["Total Volume"] = options.groupby(by)["volume"].sum()
    data["Call Volume"] = options[options["option_type"] == "call"].groupby(by)["volume"].sum()
    data["Put Volume"] = options[options["option_type"] == "put"].groupby(by)["volume"].sum()

    return data

data = filter_options_data(options, "strike")

data
# Out:
#         Total Open Interest  Call Open Interest  Put Open Interest  \
# strike
# 120.0               22821.0                74.0            22747.0
# 130.0                1506.0                19.0             1487.0
# 140.0                 488.0                 2.0              486.0
# 150.0               72684.0              2072.0            70612.0
# 155.0               12298.0                18.0            12280.0
# ...                     ...                 ...                ...
# 700.0               24945.0             24835.0              110.0
# 705.0                 478.0               478.0                0.0
# 710.0                1511.0              1511.0                0.0
# 715.0                 981.0               981.0                0.0
# 720.0              102823.0            102821.0                2.0
#
#         Total Volume  Call Volume  Put Volume
# strike
# 120.0           78.0          0.0        78.0
# 130.0           61.0          0.0        61.0
# 140.0            1.0          0.0         1.0
# 150.0           65.0          4.0        61.0
# 155.0           21.0          1.0        20.0
# ...              ...          ...         ...
# 700.0            2.0          2.0         0.0
# 705.0            0.0          0.0         0.0
# 710.0            3.0          1.0         2.0
# 715.0            0.0          0.0         0.0
# 720.0           36.0         36.0         0.0
#
# [272 rows x 6 columns]

# %%
# Do not run this cell if you are following the example above.

# In this scenario, "data" could be anything that would be displayed as a bar chart. Alternatively, it could be company fundamentals data.

# Note: This requires a valid FMP API key


symbol="AAPL"

data = obb.equity.fundamental.ratios(symbol, limit = 100, period="quarter", provider="fmp")

data.index = data.index.strftime("%Y-%m-%d")

data
# Out:
#            symbol period  current_ratio  quick_ratio  cash_ratio  \
# date
# 1998-12-26   AAPL     Q1       2.605795     2.352426    0.822776
# 1999-03-27   AAPL     Q2       2.650259     2.413212    0.879534
# 1999-06-26   AAPL     Q3       2.792723     2.600390    1.152047
# 1999-09-25   AAPL     Q4       2.766301     2.522272    0.856036
# 2000-01-01   AAPL     Q1       2.498219     2.316539    0.807125
# ...           ...    ...            ...          ...         ...
# 2022-09-24   AAPL     Q4       0.879356     0.709408    0.153563
# 2022-12-31   AAPL     Q1       0.938020     0.768724    0.149578
# 2023-04-01   AAPL     Q2       0.940354     0.764281    0.205597
# 2023-07-01   AAPL     Q3       0.981563     0.813585    0.227331
# 2023-09-30   AAPL     Q4       0.988012     0.843312    0.206217
#
#             days_of_sales_outstanding  days_of_inventory_outstanding  \
# date
# 1998-12-26                  48.052632                       1.832248
# 1999-03-27                  47.294118                       1.437445
# 1999-06-26                  51.758665                       0.557029
# 1999-09-25                  45.875749                       1.890756
# 2000-01-01                  34.263764                       0.777650
# ...                               ...                            ...
# 2022-09-24                  60.833315                       8.551997
# 2022-12-31                  41.622138                       9.185598
# 2023-04-01                  34.068392                      12.738933
# 2023-07-01                  43.115762                      14.577604
# 2023-09-30                  61.327069                      11.611542
#
#             operating_cycle  days_of_payables_outstanding  \
# date
# 1998-12-26        49.884879                     48.004886
# 1999-03-27        48.731562                     63.167702
# 1999-06-26        52.315694                     63.023873
# 1999-09-25        47.766505                     76.764706
# 2000-01-01        35.041414                     60.864055
# ...                     ...                           ...
# 2022-09-24        69.385312                    110.859542
# 2022-12-31        50.807736                     78.007542
# 2023-04-01        46.807325                     73.118615
# 2023-07-01        57.693367                     92.607747
# 2023-09-30        72.938611                    114.833405
#
#             cash_conversion_cycle  ...  price_earnings_ratio  \
# date                               ...
# 1998-12-26               1.879993  ...              8.732568
# 1999-03-27             -14.436140  ...              8.397059
# 1999-06-26             -10.708179  ...              7.484225
# 1999-09-25             -28.998201  ...             23.552897
# 2000-01-01             -25.822641  ...             22.618570
# ...                           ...  ...                   ...
# 2022-09-24             -41.474230  ...             29.094281
# 2022-12-31             -27.199806  ...             17.208993
# 2023-04-01             -26.311290  ...             26.938138
# 2023-07-01             -34.914381  ...             38.288645
# 2023-09-30             -41.894793  ...             29.085850
#
#             price_to_free_cash_flows_ratio  \
# date
# 1998-12-26                       24.355053
# 1999-03-27                       18.137648
# 1999-06-26                       75.027047
# 1999-09-25                       51.769733
# 2000-01-01                       49.423264
# ...                                    ...
# 2022-09-24                      115.723695
# 2022-12-31                       68.334817
# 2023-04-01                      101.516990
# 2023-07-01                      125.370206
# 2023-09-30                      137.421101
#
#             price_to_operating_cash_flows_ratio  price_cash_flow_ratio  \
# date
# 1998-12-26                            23.808976              23.808976
# 1999-03-27                            16.856551              16.856551
# 1999-06-26                            69.058986              69.058986
# 1999-09-25                            47.970120              47.970120
# 2000-01-01                            44.388186              44.388186
# ...                                         ...                    ...
# 2022-09-24                            99.948206              99.948206
# 2022-12-31                            60.724643              60.724643
# 2023-04-01                            91.152020              91.152020
# 2023-07-01                           115.423282             115.423282
# 2023-09-30                           123.658630             123.658630
#
#             price_earnings_to_growth_ratio  price_sales_ratio  dividend_yield  \
# date
# 1998-12-26                        0.203760           3.104913        0.000000
# 1999-03-27                       -0.699755           2.963668        0.000000
# 1999-06-26                        0.178003           3.900636        0.000000
# 1999-09-25                       -0.467319           7.827460        0.000000
# 2000-01-01                        0.350588           7.066493        0.000000
# ...                                    ...                ...             ...
# 2022-09-24                        3.879237          26.750498        0.001536
# 2022-12-31                        0.369993          17.625873        0.001825
# 2023-04-01                       -1.414252          27.450564        0.001402
# 2023-07-01                       -2.253139          37.224668        0.001264
# 2023-09-30                        1.846951          29.841774        0.001407
#
#             enterprise_value_multiple  price_fair_value  calendarYear
# date
# 1998-12-26                  28.650009          2.760999          1999
# 1999-03-27                  62.597153          2.084787          1999
# 1999-06-26                 209.281398          2.046192          1999
# 1999-09-25                  70.913430          3.369035          1999
# 2000-01-01                  58.063853          3.750973          2000
# ...                               ...               ...           ...
# 2022-09-24                  90.344514         47.589406          2022
# 2022-12-31                  55.366190         36.401387          2023
# 2023-04-01                  86.117046         41.882005          2023
# 2023-07-01                 135.913479         50.517075          2023
# 2023-09-30                  92.900618         42.975881          2023
#
# [100 rows x 57 columns]

# %%
# Create a widget for selecting the data to display.

clear_output(wait = False)

data_choices = data.columns.tolist()
data_selection = widgets.Dropdown(
    options = data_choices,
    value = None,
)
output = widgets.Output()


def generate_figure(data, data_choice):
    data = data[data[data_choice].notnull()]
    fig = go.Figure()
    fig.add_bar(
        y = data[data_choice][data[data_choice] > 0].values,
        x = data[data_choice][data[data_choice] > 0].index,
        name = data_choice,
        marker = dict(color = "blue"),
    )
    fig.add_bar(
        y = data[data_choice][data[data_choice] < 0].values,
        x = data[data_choice][data[data_choice] < 0].index,
        name = data_choice,
        marker = dict(color = "red")
    )
    fig.update_xaxes(type="category")
    fig.update_traces(width=0.98, selector=dict(type="bar"))
    fig.update_layout(
        showlegend=False,
        width=1400,
        height=600,
        title = dict(
            text=f"{symbol} {data_choice.replace('_', ' ').title()}",
            xanchor = "center",
            x = 0.5,
            font = dict(size = 20)
        ),
        barmode="overlay",
        bargap=0,
        bargroupgap=0,
        yaxis=dict(
            ticklen=0,
            showgrid=True,
            tickfont=dict(size=14),
        ),
        xaxis=dict(
            showgrid=False,
            autorange=True,
            tickangle=90,
            tickfont=dict(size=11),
        ),
    )
    return fig

def on_value_change(change):
    clear_output(wait = True)
    display(data_selection)
    with output:
        data_selection.value

data_selection.observe(on_value_change, names="value")
display(data_selection)

# Select from the drop-down menu below.
# Out:
# Dropdown(options=('Total Open Interest', 'Call Open Interest', 'Put Open Interest', 'Total Volume', 'Call Volu…

# %%
# Play this cell to display the choice

if data_selection.value is not None:

    generate_figure(data, data_selection.value).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.27.0.min.js"></script>                <div id="bd364da0-3ff3-405a-a34f-67ffc2e881f9" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd364da0-3ff3-405a-a34f-67ffc2e881f9")) {                    Plotly.newPlot(                        "bd364da0-3ff3-405a-a34f-67ffc2e881f9",                        [{"marker":{"color":"blue"},"name":"Total Open Interest","x":[120.0,130.0,140.0,150.0,155.0,160.0,165.0,170.0,175.0,180.0,185.0,190.0,195.0,200.0,205.0,210.0,215.0,220.0,225.0,230.0,235.0,240.0,245.0,250.0,255.0,260.0,265.0,270.0,275.0,280.0,285.0,290.0,295.0,300.0,305.0,310.0,315.0,320.0,325.0,326.0,327.0,328.0,329.0,330.0,331.0,332.0,333.0,334.0,335.0,336.0,337.0,338.0,339.0,340.0,341.0,342.0,343.0,344.0,345.0,346.0,347.0,348.0,349.0,350.0,351.0,352.0,353.0,354.0,355.0,356.0,357.0,358.0,359.0,360.0,361.0,362.0,363.0,364.0,365.0,366.0,367.0,368.0,369.0,370.0,371.0,372.0,373.0,374.0,375.0,376.0,377.0,378.0,379.0,380.0,381.0,382.0,383.0,384.0,385.0,386.0,387.0,388.0,389.0,390.0,391.0,392.0,393.0,394.0,395.0,396.0,397.0,398.0,399.0,400.0,401.0,402.0,403.0,404.0,405.0,406.0,407.0,407.5,408.0,409.0,410.0,411.0,412.0,412.5,413.0,414.0,415.0,416.0,417.0,417.5,418.0,419.0,420.0,421.0,422.0,422.5,423.0,424.0,425.0,426.0,427.0,427.5,428.0,429.0,430.0,431.0,432.0,432.5,433.0,434.0,435.0,436.0,437.0,437.5,438.0,439.0,440.0,441.0,442.0,442.5,443.0,444.0,445.0,446.0,447.0,447.5,448.0,449.0,450.0,451.0,452.0,452.5,453.0,454.0,455.0,456.0,457.0,457.5,458.0,459.0,460.0,461.0,462.0,462.5,463.0,464.0,465.0,466.0,467.0,468.0,469.0,470.0,471.0,472.0,473.0,474.0,475.0,476.0,477.0,478.0,479.0,480.0,481.0,482.0,483.0,484.0,485.0,486.0,487.0,488.0,489.0,490.0,491.0,492.0,493.0,494.0,495.0,496.0,497.0,498.0,499.0,500.0,501.0,505.0,510.0,515.0,520.0,525.0,530.0,535.0,540.0,545.0,550.0,555.0,560.0,565.0,570.0,575.0,580.0,585.0,590.0,595.0,600.0,605.0,610.0,615.0,620.0,625.0,630.0,635.0,640.0,645.0,650.0,655.0,660.0,665.0,670.0,675.0,680.0,685.0,690.0,695.0,700.0,705.0,710.0,715.0,720.0],"y":[22821.0,1506.0,488.0,72684.0,12298.0,10083.0,10038.0,8360.0,9993.0,37606.0,32521.0,29836.0,20895.0,85139.0,24243.0,36551.0,26012.0,56622.0,23829.0,33532.0,17942.0,60632.0,35338.0,56527.0,18032.0,30316.0,30396.0,50209.0,61207.0,37026.0,50770.0,45185.0,65071.0,159070.0,53484.0,60967.0,57744.0,129600.0,109020.0,2146.0,722.0,2169.0,1340.0,133922.0,1021.0,600.0,6250.0,3915.0,98360.0,2251.0,1611.0,1133.0,1853.0,233517.0,2456.0,2804.0,2161.0,1495.0,209334.0,3899.0,5856.0,2493.0,4623.0,351448.0,6703.0,3386.0,3971.0,9834.0,239268.0,11716.0,7837.0,10534.0,13891.0,346649.0,5110.0,6728.0,4857.0,6349.0,241408.0,7327.0,17883.0,5797.0,10619.0,343956.0,7276.0,10860.0,24680.0,6971.0,285228.0,34212.0,8126.0,18856.0,12456.0,396584.0,12257.0,13430.0,15293.0,8502.0,355884.0,28496.0,8962.0,18364.0,10199.0,387739.0,19228.0,26884.0,38312.0,18468.0,317318.0,17398.0,52484.0,43708.0,20780.0,837400.0,30090.0,68012.0,59031.0,37417.0,479691.0,36668.0,72792.0,6570.0,54367.0,33032.0,413051.0,52289.0,72313.0,5688.0,86823.0,85569.0,384574.0,99860.0,47672.0,2956.0,48813.0,60772.0,573979.0,58836.0,87094.0,7284.0,83241.0,86451.0,325378.0,54454.0,82792.0,8865.0,74976.0,58801.0,554627.0,78622.0,134847.0,9534.0,84599.0,98230.0,388402.0,79630.0,78821.0,16208.0,103767.0,85884.0,579060.0,84556.0,94083.0,9933.0,84010.0,107284.0,419216.0,104896.0,157843.0,13630.0,140469.0,116466.0,580880.0,103277.0,140617.0,419.0,135349.0,135063.0,464252.0,155421.0,151442.0,264.0,132704.0,86808.0,540118.0,70502.0,95487.0,464.0,47076.0,58790.0,216515.0,45784.0,43140.0,36199.0,24123.0,227538.0,41618.0,39258.0,24366.0,25858.0,149346.0,33728.0,20640.0,22863.0,13496.0,256224.0,17288.0,18526.0,13245.0,9592.0,78595.0,6223.0,10567.0,6595.0,4966.0,102532.0,7202.0,4953.0,14529.0,119 ...
